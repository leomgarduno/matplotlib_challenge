# %% [markdown]
# # Observations & Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

#tudy_results.head()
#mouse_metadata.head()

# %%
# Combine the data into a single dataset
combined_df = pd.merge(mouse_metadata, study_results, how='outer', on="Mouse ID")

# Display the data table for preview
combined_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
 # Checking the number of mice.
mice_number = combined_df["Mouse ID"].nunique()
mice_number
# Out:
# 249

# %%
 # Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

duplicate_mice = combined_df[combined_df.duplicated(subset=['Mouse ID','Timepoint'])].nunique
duplicate_mice
# Out:
# <bound method DataFrame.nunique of     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1  >

# %%
# Optional: Get all the data for the duplicate mouse ID. 
data_g989_df = combined_df.loc[combined_df["Mouse ID"] == "g989", :]
data_g989_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
indexg989 = combined_df[combined_df['Mouse ID'] == 'g989'].index
clean_df = combined_df.drop(indexg989)
clean_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
 # Checking the number of mice in the clean DataFrame.
clean_mice_count = drop_df["Mouse ID"].nunique()
clean_mice_count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5a7d10ca0c34> in <module>
#       1 # Checking the number of mice in the clean DataFrame.
# ----> 2 clean_mice_count = drop_df["Mouse ID"].nunique()
#       3 clean_mice_count
#
# NameError: name 'drop_df' is not defined

# %% [markdown]
# # Summary statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

regimen_mean = clean_df['Tumor Volume (mm3)'].groupby(clean_df['Drug Regimen']).mean()
regimen_median = clean_df['Tumor Volume (mm3)'].groupby(clean_df['Drug Regimen']).median()
regimen_var = clean_df['Tumor Volume (mm3)'].groupby(clean_df['Drug Regimen']).var()
regimen_std = clean_df['Tumor Volume (mm3)'].groupby(clean_df['Drug Regimen']).std()
regimen_sem = clean_df['Tumor Volume (mm3)'].groupby(clean_df['Drug Regimen']).sem()

summary_statistics_df = pd.DataFrame({"Mean Tumor Volume" : regimen_mean,
                        "Median Tumor Volume" : regimen_median,
                        "Variance Tumor Volume" : regimen_var,
                        "Std. Dev. Tumor Volume" : regimen_std,
                        "SEM Tumor Volume" : regimen_sem})
summary_statistics_df

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Using the aggregation method, produce the same summary statistics in a single line

groupby_drugregimen = clean_df.groupby("Drug Regimen")
agg_stats = groupby_drugregimen[['Tumor Volume (mm3)']].agg(['mean', 'median', 'var', 'std', 'sem'])
agg_stats
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# # Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
total_treatments = combined_df["Drug Regimen"].value_counts()
total_treatments

plot_total_treatments = total_treatments.plot.bar(color="b")


plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice")
plt.title("Number of Mice per Treatment")

plt.show()

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
x_axis = total_treatments.index.values
y_axis = total_treatments.values
plt.bar(x_axis, y_axis, color="b")

plt.xticks(rotation="vertical")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice")
plt.title("Number of Mice per Treatment")

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gender_count = clean_df["Sex"].value_counts()
gender_count
explode = (0.1, 0)
colors = ['orange', 'blue']
gender_plot = gender_count.plot.pie(explode= explode, colors = colors, autopct="%1.1f%%")
plt.title("Gender Percentage")

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
colors = ['orange', 'blue']
plt.title("Gender Percentage")
gender_plot = gender_count.plot.pie(explode= explode, colors = colors, autopct="%1.1f%%")
explode = (0.1, 0)

plt.show()

# %% [markdown]
# # Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens: 
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Start by getting the last (greatest) timepoint for each mouse

#final_tumor_volume = clean_df.groupby(["Drug Regimen", "Mouse ID"]).max()["Timepoint"]
final_tumor_volume = clean_df.groupby(["Drug Regimen", "Mouse ID"])
timepoint = final_tumor_volume['Timepoint'].max()
timepoint

#final_tumor_volume = clean_df.groupby(["Drug Regimen", "Mouse ID"]).max()["Timepoint"]
#final_tumor_volume_df = pd.DataFrame(final_tumor_volume)
#final_tumor_volume_df.head()

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

merged_timepoint_df = pd.merge(clean_df, timepoint, on=('Mouse ID', 'Timepoint'), how='inner')
merged_timepoint_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       k403     Ramicane    Male          21          16         45
# 1       s185    Capomulin  Female           3          17         45
# 2       x401    Capomulin  Female          16          15         45
# 3       m601    Capomulin    Male          22          17         45
# 4       g791     Ramicane    Male          11          16         45
# ..       ...          ...     ...         ...         ...        ...
# 243     z314     Stelasyn  Female          21          28          5
# 244     z435     Propriva  Female          12          26         10
# 245     z581    Infubinol  Female          24          25         45
# 246     z795     Naftisol  Female          13          29         45
# 247     z969     Naftisol    Male           9          30         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             22.050126                 1
# 1             23.343598                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data =[]

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
quartiles = merged_timepoint_df['Tumor Volume (mm3)'].quantile([0.25,0.5,0.75])

lowquart = quartiles[0.25]
upquart = quartiles[0.75]
IQR = upquart - lowquart

# Locate the rows which contain mice on each drug and get the tumor volumes
   
capomulin = merged_timepoint_df.loc[merged_timepoint_df["Drug Regimen"] == "Capomulin"]['Tumor Volume (mm3)'] 
ramicane = merged_timepoint_df.loc[merged_timepoint_df["Drug Regimen"] == "Ramicane"]['Tumor Volume (mm3)'] 
infubinol = merged_timepoint_df.loc[merged_timepoint_df["Drug Regimen"] == "Infubinol"]['Tumor Volume (mm3)'] 
ceftamin = merged_timepoint_df.loc[merged_timepoint_df["Drug Regimen"] == "Ceftamin"]['Tumor Volume (mm3)'] 
    
# add subset 
    
tumor_vol_data = [capomulin, ramicane, infubinol, ceftamin]  
    
# Determine outliers using upper and lower bounds
    
lower_bound = lowquart - (1.5*IQR)
upper_bound = upquart + (1.5*IQR)
print({lower_bound})
print({upper_bound})
# Out:
# {17.109230961249963}
# {93.82025999125004}

# %%
 # Generate a box plot of the final tumor volume of each mouse across four regimens of interest
